# %%
from copy import deepcopy

import numpy as np
import pandas as pd
import cv2
import os
import os.path as osp

from tqdm import tqdm
from ioutils import load_pickle
from process_video import process_video, video_results_to_submission_format

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
annotations_path = "/home/marek/Work/COOOL_benchmark/coool/data/annotations_public.pkl"
annotations = load_pickle(annotations_path)
video_root = "/home/marek/datasets/coool-benchmark"

for video_name in annotations.keys():#Check that videos exist
    assert osp.exists(os.path.join(video_root, f"{video_name}.mp4"))

# %%
submission_results = {}

video_names = sorted(list(annotations.keys()))
for video_name in tqdm(video_names, total=len(video_names)):
    video_path = osp.join(video_root, f"{video_name}.mp4")
    video_results = process_video(video_path, annotations, run_tracks=False, run_captions=False)
    _submission_results = video_results_to_submission_format(video_results)
    submission_results.update(_submission_results)


df = pd.DataFrame.from_dict(submission_results, orient="index")
df.index.name = "ID"
# Out:
# 100%|██████████| 200/200 [01:19<00:00,  2.51it/s]

# %%
remove_cols = ["Hazard_Track_ ", "Hazard_Name_ "]
df.drop(remove_cols, axis="columns", inplace=True, errors="ignore")
df
# Out:
#                 Driver_State_Changed Hazard_Track_0 Hazard_Name_0  \
# ID
# video_0001_0                   False
# video_0001_1                   False
# video_0001_2                   False
# video_0001_3                   False
# video_0001_4                   False
# ...                              ...            ...           ...
# video_0200_365                  True
# video_0200_366                  True
# video_0200_367                  True
# video_0200_368                  True
# video_0200_369                  True
#
#                Hazard_Track_1 Hazard_Name_1 Hazard_Track_2 Hazard_Name_2  \
# ID
# video_0001_0
# video_0001_1
# video_0001_2
# video_0001_3
# video_0001_4
# ...                       ...           ...            ...           ...
# video_0200_365
# video_0200_366
# video_0200_367
# video_0200_368
# video_0200_369
#
#                Hazard_Track_3 Hazard_Name_3 Hazard_Track_4  ...  \
# ID                                                          ...
# video_0001_0                                                ...
# video_0001_1                                                ...
# video_0001_2                                                ...
# video_0001_3                                                ...
# video_0001_4                                                ...
# ...                       ...           ...            ...  ...
# video_0200_365                                              ...
# video_0200_366                                              ...
# video_0200_367                                              ...
# video_0200_368                                              ...
# video_0200_369                                              ...
#
#                Hazard_Track_18 Hazard_Name_18 Hazard_Track_19 Hazard_Name_19  \
# ID
# video_0001_0
# video_0001_1
# video_0001_2
# video_0001_3
# video_0001_4
# ...                        ...            ...             ...            ...
# video_0200_365
# video_0200_366
# video_0200_367
# video_0200_368
# video_0200_369
#
#                Hazard_Track_20 Hazard_Name_20 Hazard_Track_21 Hazard_Name_21  \
# ID
# video_0001_0
# video_0001_1
# video_0001_2
# video_0001_3
# video_0001_4
# ...                        ...            ...             ...            ...
# video_0200_365
# video_0200_366
# video_0200_367
# video_0200_368
# video_0200_369
#
#                Hazard_Track_22 Hazard_Name_22
# ID
# video_0001_0
# video_0001_1
# video_0001_2
# video_0001_3
# video_0001_4
# ...                        ...            ...
# video_0200_365
# video_0200_366
# video_0200_367
# video_0200_368
# video_0200_369
#
# [55770 rows x 47 columns]

# %%
df.to_csv("../submissions/results_20122024_bboxsizes_driver.csv", sep=",")
